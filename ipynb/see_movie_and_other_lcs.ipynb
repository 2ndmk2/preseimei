# %%
import numpy as np
import matplotlib.pyplot as plt
from preseimei import movie_lc_ana
import glob
import importlib

def show_movie_sum(movie, dt = 20, dt2=10):
    for i in range(int(len(movie)/dt)):
        movie_now = np.sum(movie[dt* i: dt*i + dt2], axis=0)
        plt.imshow(np.log10(movie_now ))
        plt.show()
        print("%d/%d" % (dt*i, len(movie)))
apertures = [10, 15, 20, 25]
bin_t = 10
obj_name = "WD_new25"
obs_date = "20220111"
band = "g_band"
rp = 20
out_dir = "/alps/south/reduced/%s_analyzed/movies/%s/%s/" % (obs_date, obj_name, band)
lc_file = glob.glob(out_dir + "target_and_others_*_lc%d.npz" % rp)[0]
gaia_id= lc_file.split("_")[-2]
d_movie = np.load(out_dir + "movie_after_bkgsub_%s.npz" % gaia_id)

# %%
lcs = np.load(lc_file)
time = lcs["time"]
flux_target =lcs["time"]
flux_for_comp = lcs["flux_for_comp"]
print(lcs.files)
# Out:
# ['time', 'flux_target', 'flux_for_comp', 'gaia_for_comp']

# %%
for i in range(len(flux_for_comp)):

    plt.plot(time, flux_for_comp[i])
    plt.show()

# %%
see_movie = True
if see_movie:
    movie= d_movie["movie"]
    show_movie_sum(movie)
# Out:
# <ipython-input-50-5174c48cd9f1>:10: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(movie_now ))
# 0/1800
# 20/1800
# 40/1800
# 60/1800
# 80/1800
# 100/1800
# 120/1800
# 140/1800
# 160/1800
# 180/1800
# 200/1800
# 220/1800
# 240/1800
# 260/1800
# 280/1800
# 300/1800
# 320/1800
# 340/1800
# 360/1800
# 380/1800
# 400/1800
# 420/1800
# 440/1800
# 460/1800
# 480/1800
# 500/1800
# 520/1800
# 540/1800
# 560/1800
# 580/1800
# 600/1800
# 620/1800
# 640/1800
# 660/1800
# 680/1800
# 700/1800
# 720/1800
# 740/1800
# 760/1800
# 780/1800
# 800/1800
# 820/1800
# 840/1800
# 860/1800
# 880/1800
# 900/1800
# 920/1800
# 940/1800
# 960/1800
# 980/1800
# 1000/1800
# 1020/1800
# 1040/1800
# 1060/1800
# 1080/1800
# 1100/1800
# 1120/1800
# 1140/1800
# 1160/1800
# 1180/1800
# 1200/1800
# 1220/1800
# 1240/1800
# 1260/1800
# 1280/1800
# 1300/1800
# 1320/1800
# 1340/1800
# 1360/1800
# 1380/1800
# 1400/1800
# 1420/1800
# 1440/1800
# 1460/1800
# 1480/1800
# 1500/1800
# 1520/1800
# 1540/1800
# 1560/1800
# 1580/1800
# 1600/1800
# 1620/1800
# 1640/1800
# 1660/1800
# 1680/1800
# 1700/1800
# 1720/1800
# 1740/1800
# 1760/1800
# 1780/1800

# %%
import numpy as np
import os
from preseimei import movie_lc_ana
import matplotlib.pyplot as plt
time_offset = 5148650000

obs_date = "20220111"
target = "WD_triccs28"
dir_lc ="/alps/south/reduced/%s_analyzed/movies/%s/g_band" % (obs_date, target)
r_ap = 20
bin_t = 10

lc_all = np.load(os.path.join(dir_lc, "all_lcs%d.npz" % (r_ap)), allow_pickle=True)
time = lc_all["time"]
flux = lc_all["flux"]
for i in range(len(time)):
    plt.plot(time[i], flux[i]/np.median(flux[i]))
    plt.show()
