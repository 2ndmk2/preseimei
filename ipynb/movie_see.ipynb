# %%
import numpy as np
import matplotlib.pyplot as plt
from preseimei import movie_lc_ana
import glob
import importlib

apertures = [10, 15, 20, 25]
bin_t = 10
obs_date = "20220113"
out_dir = "/alps/south/reduced/%s_analyzed/movies/WD_new13/g_band/" % obs_date
names = glob.glob(out_dir + "target_processed_*_lc10.npz")
gaia_id= names[0].split("_")[-2]
d_movie = np.load(out_dir + "movie_after_bkgsub_%s.npz" % gaia_id)

# %%
def show_movie_sum(movie, dt = 20, dt2=3):
    for i in range(int(len(movie)/dt)):
        movie_now = np.sum(movie[dt* i: dt*i + dt2], axis=0)
        plt.imshow(np.log10(movie_now ))
        plt.show()
        print(i, len(movie)/dt)
movie= d_movie["movie"]

show_movie_sum(movie)
# Out:
# <ipython-input-9-f50cfd0ff5f1>:4: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(movie_now ))
# 0 42.0
# 1 42.0
# 2 42.0
# 3 42.0
# 4 42.0
# 5 42.0
# 6 42.0
# 7 42.0
# 8 42.0
# 9 42.0
# 10 42.0
# 11 42.0
# 12 42.0
# 13 42.0
# 14 42.0
# 15 42.0
# 16 42.0
# 17 42.0
# 18 42.0
# 19 42.0
# 20 42.0
# 21 42.0
# 22 42.0
# 23 42.0
# 24 42.0
# 25 42.0
# 26 42.0
# 27 42.0
# 28 42.0
# 29 42.0
# 30 42.0
# 31 42.0
# 32 42.0
# 33 42.0
# 34 42.0
# 35 42.0
# 36 42.0
# 37 42.0
# 38 42.0
# 39 42.0
# 40 42.0
# 41 42.0

# %%
plt.imshow(movie_sum )
